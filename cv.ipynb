# %% [raw]
# ---
# title: "CV"
# ---

# %% [markdown]
# ## Education
#
# -   **University of Vienna** (Vienna, Austria)
#     -   Doctoral Program in Political Science (09/2022 - present)
#         -   Supervisor: Prof. Thomas Meyer, PhD
#         -   Co-supervisor: Prof. Dr. Laurenz Ennser-Jedenastik
# -   **Central European University** (Vienna, Austria)
#     -   MA in Political Science (09/2021 - 06/2022)
# -   **Soka University** (Tokyo, Japan)
#     -   Master of Laws (04/2013 - 03/2015)
# -   **Centro Universitário de Brasília** (Brasília, Brazil)
#     -   BA in International Relations (01/2002 - 09/2006)
#
# ## Research experience
#
# -   The Politics of Portfolio Design in European Democracies (09/2022 - present)
#
#     -   PI: Thomas Meyer, PhD (University of Vienna)
#
#     -   PI: Dr. Ulrich Sieberer (University of Bamberg)
#
#     -   Funded by the Austrian Science Fund (grant number: I 5876-G) and the German Research Foundation (grant number: SI 1470/9-1).
#
# ## Additional Academic Training
#
# ### Summer Schools
#
# -   Essex Summer School in Social Science Data Analysis (Colchester, UK)
#
#     -   Introduction to Web Scraping and Data Management for Social Scientists (07/2023 - 08/2023)
#
# ### Workshops
#
# -   University of Vienna Graduate School of Social Sciences (Vienna, Austria)
#
#     -   "Unleashing the Potential of Geography in Social Sciences: An Introduction to GIS with R" (06/2023)
#
# -   Voter Perceptions of Post-Election Outcomes (Vienna, Austria)
#     & \\hfill 05/2023\\\\
#
# ### Others
#
# -   Maastricht University / UNU-MERIT (Maastricht, the Netherlands)
#
#     -   Evidence-Based Policy Research Methods (01/2019 - 04/2020)
#
# -   Universidade de Brasília (Brasília, Brazil)
#
#     -   Lato sensu Graduate Degree in International Relations (03/2008 - 05/2009)
#
# ## Honors and Scholarships
#
# -   Central European University Tuition Waiver Scholarship (2021)
#
#     -   6,000 EUR
#
# -   Ministry of Education, Culture, Sports, Science and Technology of Japan (MEXT) Scholarship (2014)
#
#     -   1,088,000 JPY (approx. 8,000 EUR)
#
# -   Soka University Scholarship for International Students (2014)
#
#     -   360,000 JPY (approx. 2,700 EUR)
#
# -   Soka University Scholarship for International Students (2013)
#
#     -   360,000 JPY (approx. 2,700 EUR)
#
#
# ```{latex}
#
# & Soka University Scholarship for International Students,  \hfill 2014 \\ & (360,000 JPY -- approx. 2,700 EUR)\\
# & Soka University Scholarship for International Students,  \hfill 2013 \\ & (360,000 JPY -- approx. 2,700 EUR)\\
# & \\
#
# %{{Awards}}
# %& Soka University Da Vinci Award - category: language excellency  \hfill 2015 \\
# %&\\
#
#
# % --- Section: Various skills (programming, software, languages, etc.) ---
# {{Skills}}
# & \textbf{Languages}\\
# & Portuguese (native), English (fluent), Japanese (fluent), Spanish (basic), French (basic), German (beginner). \\
# & \\
#
# & \textbf{Computer skills} \\
# & Statistical software: R. \\
# & Programming languages: HTML. \\
# & General applications: LaTeX, MAXQDA, MS Office, MacOS, Windows.\\
# & \\
#
# % --- Section: Conferences --
#
# {{Conferences}}
# & {\textbf{Paper presenter}}\\
# & {ECPR 8th Conference of the Standing} \hfill Vienna, Austria\\
# & {Group on Parliaments} \hfill 07/2023\\
# & \\
#
# % --- Section: Industry experience ---
#
# {{Industry experience}}
# & {\textbf{Soka University,}} International Affairs Office \hfill Tokyo, Japan\\
# & Administrative analyst \hfill 04/2015 -- 12/2020 \\
# & \\
#
# & {\textbf{Patri Politicas Publicas,}} Legislative Sector \hfill Brasília, Brazil\\
# & Government Relations analyst \hfill 10/2011 -- 03/2012 \\
# & \\
#
# & {\textbf{Federal District Regional Board of Nursing,}}  \hfill Brasília, Brazil\\
# & Assistant to the President \hfill 09/2010 -- 10/2011 \\
# & \\
#
#
# % --- Section: Additional training --
#
# {{Additional training}}
# & {\textbf{Central European University,}}  \hfill Vienna, Austria\\
# {{and internships}}
# & Student Ambassador at Department of Political Science \hfill 10/2021 -- 01/2022 \\
# & Intern at Student Recruitment Office \hfill 10/2021 -- 06/2022 \\
# & \\
#
# & {\textbf{Soka University,}}  \hfill Tokyo, Japan\\
# & Assistant at International Research Institute for \hfill 09/2013 -- 03/2015 \\ & Advanced Buddhology \\
# & English Instructor at World Language Center \hfill 09/2012 -- 01/2015 \\
# & \\
#
# & {\textbf{Patri Politicas Publicas,}}   \hfill Brasília, Brazil\\
# & Trainee at Legislative Sector \hfill 03/2010 -- 06/2010 \\
# & \\
#
#
# % References
#
# %{{References}} & \textbf{Daniel Bochsler, PhD} \hfill Central European University,\\
# %& \href{mailto: bochslerd@ceu.edu}{bochslerd@ceu.edu}  \hfill Associate Professor \\
# %& \\
# %& \textbf{Mariyana Angelova, PhD} \hfill Central European University, \\
# %& \href{mailto: angelovam@ceu.edu}{angelovam@ceu.edu}  \hfill Assistant Professor\\
# %& \\
#
# % --- End of CV! ---
#
# \end{longtable}
# \end{document}
#
# ```
